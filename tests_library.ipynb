# %%
import pandas as pd
import unittest
from EDA  import dataEnrich

# %%
#write unittest script
#create dataframe with 2 columns of dates
#apply function to dataframe to create third column
#compare values in thriird column to expected values.

data = pd.read_csv("data/books_clean.csv", usecols=["Book checkout", "Book Returned"])

def dataEnrich(col1, col2):
    #logic
    col1=df
    colout = col2 - col1
    return df

#enrichedDF = dataEnrich(df=data,outputCol=, col1=, col2= )
# Out:
#   Cell In[4], line 14
#     enrichedDF = dataEnrich(df=data,outputCol=, col1=, col2= )
#                                               ^
# SyntaxError: invalid syntax
